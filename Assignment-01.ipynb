# %%
from IPython.core.display import HTML
def css_styling():
    styles = open("../styles/custom.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <link href='http://fonts.googleapis.com/css?family=Fenix' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Source+Code+Pro:300,400' rel='stylesheet' type='text/css'>
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
#     }
#     div.cell{
#         width:800px;
#         margin-left:5% !important;
#         margin-right:auto;
#     }
#     h1 {
#         font-family: 'Alegreya Sans', sans-serif;
#     }
#     h2 {
#         font-family: 'Alegreya Sans', sans-serif;
#         color:#CD2305;
#     }
#     h3{
# 		font-family: 'Fenix', serif;
#         margin-top:12px;
#         margin-bottom: 3px;
#         color:#CD2305;
#        }
# 	h4{
# ...

# %% [markdown]
# <figure>
# <IMG SRC="../lectures/images/PhysicsLogo.jpg" WIDTH=100 ALIGN="right">
# </figure>
# # [Physics 411](http://jklymak.github.io/Phy411/) Time Series Analysis
# *Jody Klymak*

# %% [markdown]
# # Assignment 1

# %% [markdown]
# ## Q1: Simulate aliasing of sinusoidal signals

# %% [markdown]
# For this problem you will simulate the phenomena of aliasing.  This will give you pracitice in making synthetic time series, subsetting data, and plotting your results.
#
# **1** To start, make a time vector that goes from 0 to 100 s, with 10000 entries in it.  Then make a synthetic time series that has two close in frequency sine waves:
#
# $$ x = A_1 \cos (\omega t) + A_2 \cos ((\omega+\delta \omega ) t) $$
#
# where $\omega$ is the "carrier" frequency, and $\delta \omega << \omega$ is the difference in frequencies between the two waves.  For simplicty, you could make $A_1=A_2=1.0\ [V]$.  Feel free to choose an interesting $\omega$.
#
# <hr>

# %%
import numpy as np

t = np.linspace(0.,100.,10000)
w = 1.
dw = w/25.

a = np.cos(w*t)
b = np.cos((w+dw)*t)
x = a+b

# %% [markdown]
# **2** Now plot the two component waves and the full value of $x$ as a time series.  Preferably on the same axis.  Make sure to label your axes and include a legend<hr>

# %%
import matplotlib.pyplot as plt
% matplotlib inline

fig2 = plt.figure(figsize=(10,6))
ax =  fig2.add_subplot(1,1,1)
ax.plot(t,x,label='$\cos (\omega t)+\cos((\delta \omega +\omega)t)$')
ax.plot(t,a,label='$\cos (\omega t)$')
ax.plot(t,b,label='$\cos((\delta \omega +\omega)t$')
ax.legend(loc=1)
ax.set_xlabel('Time (s)')
ax.set_ylabel('x')
ax.set_title('$ \omega = 1, \; \delta\omega = \omega/25$')

# %% [markdown]
# **3** Try a few different values of $\delta\omega$, and compare.<hr>

# %%
w = 2.
dw = w/25.

a = np.cos(w*t)
b = np.cos((w+dw)*t)
x = a+b

fig3 = plt.figure(figsize=(10,12))
fig3.suptitle('Comparison of different $\omega$ and $\delta\omega$')
ax1 =  fig3.add_subplot(2,1,1)
ax1.plot(t,x,label='$\cos (\omega t)+\cos(\delta \omega +\omega)t)$')
ax1.plot(t,a,label='$\cos (\omega t)$')
ax1.plot(t,b,label='$\cos(\delta \omega +\omega)t$')
ax1.legend(loc=1)
ax1.set_xlabel('Time (s)')
ax1.set_ylabel('x')
ax1.set_title('$ \omega = 2, \; \delta\omega = \omega/25$')

w = 1.
dw = w/15.

a = np.cos(w*t)
b = np.cos((w+dw)*t)
x = a+b

ax2 =  fig3.add_subplot(2,1,2)
ax2.plot(t,x,label='$\cos (\omega t)+\cos(\delta \omega +\omega)t)$')
ax2.plot(t,a,label='$\cos (\omega t)$')
ax2.plot(t,b,label='$\cos(\delta \omega +\omega)t$')
ax2.legend(loc=1)
ax2.set_xlabel('Time (s)')
ax2.set_ylabel('x')
ax2.set_title('$ \omega = 1, \; \delta\omega = \omega/15$')

# %% [markdown]
# **4** Now, just so this works, let me specify some numbers for you.  Make $\omega=\frac{2\pi}{3}$, and $\delta\omega=\omega/10.$.  Plot the original time series, and a subsampled time series that just consists of every 200th point.  In a "Markdown" box below the code (or as a comment) describe the difference in these two signals as quantifiably as you can.  <hr>

# %%
w = 2.*np.pi/3.
dw = w/10.

a = np.cos(w*t)
b = np.cos((w+dw)*t)
x = a+b

subsample = 200

xsub = x[::subsample]
asub = a[::subsample]
bsub = b[::subsample]
tsub = t[::subsample]

fig4=plt.figure(figsize=(10,10))

ax1=fig4.add_subplot(2,1,1)
ax1.plot(t,x,label='x')
ax1.plot(t,a,label='a')
ax1.plot(t,b,label='b')
ax1.legend(loc=1)
ax1.set_title('original time series')

ax2=fig4.add_subplot(2,1,2)
ax2.plot(tsub,xsub,label='x')
ax2.plot(tsub,asub,label='a')
ax2.plot(tsub,bsub,label='b')
ax2.legend(loc=1)
ax2.set_title('subsampled time series')

# %% [markdown]
# The subsampled time series appears to have a lower frequency than the original time series.

# %% [markdown]
# ## Q2: Demonstrate the central limit theorem for a very unfair coin flip.

# %% [markdown]
# Consider a coin that is twice as likely to come up heads as tails. To put a number on it, call tails $x=-1/2$ and heads $x=+1/2$.
#
# **1** What are the mean, $\mu_x$, and variance $\sigma_x^2$ of this process?
#
# <hr>

# %% [markdown]
# ANSWER HERE

# %%
heads = 0.500000000
tails = -0.50000000
p_heads = 0.666666667
p_tails = 0.333333333

mean = p_heads*heads + p_tails*tails
var = p_heads*(heads-mean)**2+p_tails*(tails-mean)**2
print 'mean : '+str(mean)
print 'variance : '+str(var)
# Out:
# mean : 0.166666667
# variance : 0.222222222111

# %% [markdown]
# **2** Plot or represent the *probability distribution*  (or cumulative distrubution) of this process.
# <hr>

# %%
x = [-1,tails, heads,1]
y = [0,p_tails,p_heads,1]
plt.step(x,y)
plt.title('cumulative distribution for biased coin')

# %% [markdown]
# **3** Write a function using the `np.random.norm` function to simulate the coin flip.  It shoudl return $+1/2$ twice as often as $-1/2$.  Demonstrate that your function works.
# <hr>

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
% matplotlib inline

def flip(N):

    def single_flip(p):
          return 0.5 if np.random.random() < p else -0.5

    coin_tosses = [single_flip(0.66667) for i in range(N)]
    return coin_tosses

# use itemfreq to count number of heads and tails
# divide number of heads by tails to show that heads are twice as likely
print '100 flips: '
freq = stats.itemfreq(flip(100))
print freq[1,1]/freq[0,1]

print '\n1000 flips:'
freq = stats.itemfreq(flip(1000))
print freq[1,1]/freq[0,1]
# Out:
# 100 flips:
# 2.22580645161
#
# 1000 flips:
# 1.849002849

# %% [markdown]
# **4** Perform $N_{flip}$ and take the sample mean $\overline{x}$ of the values.  Do this 2000 times, and show that as $N_{flip}\to\infty$ the distribution of $\overline{x}$ approaches a Normal distribution by plotting the histograms of the means for each.  For $N_{roll}$ choose 2, 16, 64, 256.
#
# Comment on how the convergence of $\overline{x}$ for the unfair coin compares to the convergence of the sample mean of the dice roll.
# <hr>

# %%
a = [np.mean(flip(2)) for i in range(2000)]
b = [np.mean(flip(16)) for i in range(2000)]
c = [np.mean(flip(64)) for i in range(2000)]
d = [np.mean(flip(256)) for i in range(2000)]

bins = 20

fig = plt.figure(figsize=(8,18))

ax=fig.add_subplot(4,1,1)
ax = plt.hist(a,bins)
plt.title('$N_{flip}= 2$')
plt.xlabel('mean')
plt.ylabel('frequency')

ax = fig.add_subplot(4,1,2)
ax = [plt.hist(b,bins)]
plt.title('$N_{flip}= 16$')
plt.xlabel('mean')
plt.ylabel('frequency')

ax = fig.add_subplot(4,1,3)
ax = [plt.hist(c,bins)]
plt.title('$N_{flip}= 64$')
plt.xlabel('mean')
plt.ylabel('frequency')

ax = fig.add_subplot(4,1,4)
ax = [plt.hist(d,bins)]
plt.title('$N_{flip}= 256$')
plt.xlabel('mean')
plt.ylabel('frequency')

fig =  plt.figure(figsize=(8,6))
fig.suptitle('Comparison for 2000 experiments, with varous $N_{flip}$')
ax = fig.add_subplot(1,1,1)

ax.hist(a,bins,label='2 flips',histtype='step',normed=False)
ax.hist(b,bins,label='16 flips',histtype='step',normed=False)
ax.hist(c,bins,label='64 flips',histtype='step',normed=False)
ax.hist(d,bins,label='256 flips',histtype='step',normed=False)
ax.set_xlabel('mean flip')
ax.set_ylabel('PDF (per flip increment)')
ax.legend(loc=2)

# %% [markdown]
# As the number of flips is, the distribution approaches a normal distribution, with a narrower peak. The peak is centred about the mean. This is similar to what was seen in the dice roll experiment.

# %% [markdown]
# <hr>
# **5** Replot the histograms, removing the mean and normalizing by the standard deviation.  Also show the CDF for normal distribution with mean zero and standard deviation of 1.
# <hr>

# %%
fig, ax=plt.subplots(1,1)
fig.suptitle('mean removed and normalized by the standard deviation')
bins = 30
td = [a,b,c,d]
lab = ['2 rolls','16 rolls','64 rolls','256 rolls']
histos=list()
for nn,me in enumerate(td):
    histo, bins, patches = ax.hist((me-np.mean(me))/np.std(me),bins,
                                   label=lab[nn],histtype='step',normed=True)
    histos.append(histo)
ax.set_xlabel('mean roll')
ax.set_ylabel('PDF (per roll increment)')
ax.legend(loc=1)

# CDF with normal CDF superimposed 

import matplotlib.mlab as mlab

midbins=bins[0:-1]-np.diff(bins)[0]
y = mlab.normpdf(midbins, 0, 1.)

fig,ax=plt.subplots(1,1)
fig.suptitle('CDF')
histos=list()
for nn,me in enumerate(td):
    histo, bins, patches = ax.hist((me-np.mean(me))/np.std(me),bins,
                                   label=lab[nn],histtype='step',normed=True,
                                   cumulative=True,align='right')
    histos.append(histo)
ax.set_xlabel('mean roll');ax.set_ylabel('PDF (per roll increment)')
y = stats.norm.cdf(midbins, 0, 1)
ax.plot(midbins,y,label='normal distribution')
ax.legend(loc=2)
ax.set_ylim([0,1.1])
# Out:
# (0, 1.1)

# %% [markdown]
# ## Q3: Look at the Deep Cove weather data:

# %% [markdown]
# There are two data sets, one with a sample every minute at
#
# `http://web.uvic.ca/~jklymak/Phy411/Data/MinuteData/DeepCoveNew.txt`.
#
# Download it locally, or use `genfromtxt` with the url as an argument.
#
# The second is hourly data of the same station and a lot more.
#
# `http://web.uvic.ca/~jklymak/Phy411/Data/MinuteData/AllHourly.txt`

# %%
minutedata=np.genfromtxt('http://web.uvic.ca/~jklymak/Phy411/Data/MinuteData/DeepCoveNew.txt')[:,1]
hourdata=np.genfromtxt('http://web.uvic.ca/~jklymak/Phy411/Data/AllHourly.txt')[6,2:]

#remove NaN's
minutedata = minutedata[np.isfinite(minutedata)]
hourdata = hourdata[np.isfinite(hourdata)]

# %% [markdown]
# **1** Compare the normalized histograms of the two time series.  Also calculate the means and the standard deviations.
# <hr>

# %%
fig, ax=plt.subplots(1,1)
bins = 50
td = [minutedata,hourdata]
lab = ['minute data','hour data']

histos=list()
for nn,me in enumerate(td):
    histo, bins, patches = ax.hist(me,bins,label=lab[nn],histtype='step',
                                   normed=True)
    histos.append(histo)
ax.set_xlabel('temperature')
ax.set_ylabel('pdf (per temperature increment)')
ax.legend()

min_mean = np.mean(minutedata)
min_std = np.std(minutedata)
hour_mean = np.mean(hourdata)
hour_std = np.std(hourdata)

print 'minute data:'
print 'mean: '+ str(min_mean)
print 'standard deviation: ' +str(min_std)
print ''
print 'hour data:'
print 'mean: '+ str(hour_mean)
print 'standard deviation: ' +str(hour_std)
# Out:
# minute data:
# mean: 10.3016961717
# standard deviation: 5.98530478686
#
# hour data:
# mean: 10.3387280591
# standard deviation: 6.06772257867

# %% [markdown]
# **2** Comment on the shape of these histograms.  Are they Normal?  Speculate as to why they have this shape.
# <hr>

# %% [markdown]
# The histograms do not appear to be normally distributed, which is visible by comparing the histograms to the normal distribution with the sample mean and standard deviation (see below). This could be due to uneven heating/cooling rates throghout the day. For example, in the morning, the temperature might rise to the maximum daily temperature more quickly than the temperature cools in the evening.

# %%
fig, ax=plt.subplots(1,1)
bins = 50
td = [minutedata,hourdata]
lab = ['minute data','hour data']

histos=list()
for nn,me in enumerate(td):
    histo, bins, patches = ax.hist(me,bins,label=lab[nn],histtype='step',
                                   normed=True)
    histos.append(histo)
ax.set_xlabel('temperature')
ax.set_ylabel('pdf (per temperature increment)')
ax.legend()

midbins=bins[0:-1]-np.diff(bins)[0]
y = mlab.normpdf(midbins, 10.33, 6.06)
ax.plot(midbins,y,'k--',label='Normal Dist')
ax.legend()

# %% [markdown]
# <hr>
# **3** Redo the histogram and the statistics with just the temperature at 3 PM (both time series start at midnight local time).
# <hr>

# %%
a = hourdata[15::24]
b = minutedata[15*60::24*60]

fig, ax=plt.subplots(1,1)
bins = 50
td = [c,d]
lab = ['minute data','hour data']

histos=list()
for nn,me in enumerate(td):
    histo, bins, patches = ax.hist(me,bins,label=lab[nn],histtype='step',
                                   normed=True)
    histos.append(histo)
ax.set_xlabel('temperature')
ax.set_ylabel('pdf (per temperature increment)')
ax.legend()

min_mean = np.mean(a)
min_std = np.std(a)
hour_mean = np.mean(b)
hour_std = np.std(b)

print 'minute data:'
print 'mean: '+ str(min_mean)
print 'standard deviation: ' +str(min_std)
print ''
print 'hour data:'
print 'mean: '+ str(hour_mean)
print 'standard deviation: ' +str(hour_std)
# Out:
# minute data:
# mean: 11.0903119343
# standard deviation: 6.30206191833
#
# hour data:
# mean: 8.63929510011
# standard deviation: 4.44921586916

# %% [markdown]
# **4** Redo the histogram and the statistics with just the temperature at 5 AM (both time series start at midnight local time).

# %%
c = hourdata[5::24]
d = minutedata[5*60::24*60]

fig, ax=plt.subplots(1,1)
bins = 50
td = [c,d]
lab = ['minute data','hour data']

histos=list()
for nn,me in enumerate(td):
    histo, bins, patches = ax.hist(me,bins,label=lab[nn],histtype='step',
                                   normed=True)
    histos.append(histo)
ax.set_xlabel('temperature')
ax.set_ylabel('pdf (per temperature increment)')
ax.legend()

min_mean = np.mean(c)
min_std = np.std(c)
hour_mean = np.mean(d)
hour_std = np.std(d)

print 'minute data:'
print 'mean: '+ str(min_mean)
print 'standard deviation: ' +str(min_std)
print ''
print 'hour data:'
print 'mean: '+ str(hour_mean)
print 'standard deviation: ' +str(hour_std)
# Out:
# minute data:
# mean: 10.0081319402
# standard deviation: 5.99111103818
#
# hour data:
# mean: 10.618290033
# standard deviation: 6.56947573596
